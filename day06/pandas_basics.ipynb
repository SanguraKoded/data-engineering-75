# %%
import pandas as pd

# %%
df = pd.read_json('C:\\Users\\H\\Downloads\\data-engineering-75\\day05\\weather_data_5_cities.json')

# %%
df.head(2)
# Out:
#                               coord  \
# 0  {'lon': 36.6822, 'lat': -3.3869}
# 1   {'lon': 34.7519, 'lat': 0.2827}
#
#                                              weather      base  \
# 0  [{'id': 802, 'main': 'Clouds', 'description': ...  stations
# 1  [{'id': 804, 'main': 'Clouds', 'description': ...  stations
#
#                                                 main  visibility  \
# 0  {'temp': 291.12, 'feels_like': 290.77, 'temp_m...       10000
# 1  {'temp': 289.33, 'feels_like': 289.41, 'temp_m...       10000
#
#                                                 wind       clouds          dt  \
# 0           {'speed': 2.4, 'deg': 139, 'gust': 3.21}  {'all': 27}  1790199067
# 1  {'speed': 1.4, 'deg': 45, 'gust': 1.4100000000...  {'all': 90}  1790199069
#
#                                                  sys  timezone      id  \
# 0  {'country': 'TZ', 'sunrise': 1790220119, 'suns...     10800  161325
# 1  {'country': 'KE', 'sunrise': 1790220589, 'suns...     10800  195272
#
# ...

# %%
df.tail(2)
# Out:
#                              coord  \
# 3   {'lon': 3.3792, 'lat': 6.5244}
# 4  {'lon': 18.5628, 'lat': 4.3733}
#
#                                              weather      base  \
# 3  [{'id': 801, 'main': 'Clouds', 'description': ...  stations
# 4  [{'id': 804, 'main': 'Clouds', 'description': ...  stations
#
#                                                 main  visibility  \
# 3  {'temp': 297.56, 'feels_like': 298.35, 'temp_m...       10000
# 4  {'temp': 295.92, 'feels_like': 296.73, 'temp_m...       10000
#
#                                        wind       clouds          dt  \
# 3  {'speed': 2.09, 'deg': 227, 'gust': 5.2}  {'all': 16}  1790198936
# 4  {'speed': 0.85, 'deg': 35, 'gust': 0.81}  {'all': 87}  1790199322
#
#                                                  sys  timezone       id  \
# 3  {'country': 'NG', 'sunrise': 1790141738, 'suns...      3600  2566677
# 4  {'country': 'CF', 'sunrise': 1790138095, 'suns...      3600  2389853
#
#        name  cod rain
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   coord       5 non-null      object
#  1   weather     5 non-null      object
#  2   base        5 non-null      str
#  3   main        5 non-null      object
#  4   visibility  5 non-null      int64
#  5   wind        5 non-null      object
#  6   clouds      5 non-null      object
#  7   dt          5 non-null      int64
#  8   sys         5 non-null      object
#  9   timezone    5 non-null      int64
#  10  id          5 non-null      int64
#  11  name        5 non-null      str
#  12  cod         5 non-null      int64
#  13  rain        1 non-null      object
# dtypes: int64(5), object(7), str(2)
# memory usage: 692.0+ bytes

# %%
df.describe()
# Out:
#        visibility            dt      timezone            id    cod
# count         5.0  5.000000e+00      5.000000  5.000000e+00    5.0
# mean      10000.0  1.790199e+09   6480.000000  1.525486e+06  200.0
# std           0.0  1.575960e+02   3943.602414  1.233272e+06    0.0
# min       10000.0  1.790199e+09   3600.000000  1.613250e+05  200.0
# 25%       10000.0  1.790199e+09   3600.000000  1.952720e+05  200.0
# 50%       10000.0  1.790199e+09   3600.000000  2.314302e+06  200.0
# 75%       10000.0  1.790199e+09  10800.000000  2.389853e+06  200.0
# max       10000.0  1.790199e+09  10800.000000  2.566677e+06  200.0

# %%
df["main"].iloc[0]
# Out:
# {'temp': 291.12,
#  'feels_like': 290.77,
#  'temp_min': 291.12,
#  'temp_max': 291.12,
#  'pressure': 1018,
#  'humidity': 69,
#  'sea_level': 1018,
#  'grnd_level': 870}

# %%
df["weather"].iloc[0]
# Out:
# [{'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'}]

# %%
df.isnull()
# Out:
#    coord  weather   base   main  visibility   wind  clouds     dt    sys  \
# 0  False    False  False  False       False  False   False  False  False
# 1  False    False  False  False       False  False   False  False  False
# 2  False    False  False  False       False  False   False  False  False
# 3  False    False  False  False       False  False   False  False  False
# 4  False    False  False  False       False  False   False  False  False
#
#    timezone     id   name    cod   rain
# 0     False  False  False  False   True
# 1     False  False  False  False   True
# 2     False  False  False  False  False
# 3     False  False  False  False   True
# 4     False  False  False  False   True

# %%
df.isnull().sum()
# Out:
# coord         0
# weather       0
# base          0
# main          0
# visibility    0
# wind          0
# clouds        0
# dt            0
# sys           0
# timezone      0
# id            0
# name          0
# cod           0
# rain          4
# dtype: int64

# %%
df.iloc[2]
# Out:
# coord                          {'lon': 15.2663, 'lat': -4.4419}
# weather       [{'id': 500, 'main': 'Rain', 'description': 'l...
# base                                                   stations
# main          {'temp': 301.61, 'feels_like': 302.46, 'temp_m...
# visibility                                                10000
# wind                     {'speed': 1.69, 'deg': 2, 'gust': 2.7}
# clouds                                             {'all': 100}
# dt                                                   1790198936
# sys           {'country': 'CD', 'sunrise': 1790138885, 'suns...
# timezone                                                   3600
# id                                                      2314302
# name                                                   Kinshasa
# cod                                                         200
# rain                                 {'1h': 0.6900000000000001}
# Name: 2, dtype: object

# %%
for index, row in df.iterrows():
    print(index, row['name'])
# Out:
# 0 Arusha
# 1 Kakamega
# 2 Kinshasa
# 3 Shogunle
# 4 Bangui

# %%
df['name']
# Out:
# 0      Arusha
# 1    Kakamega
# 2    Kinshasa
# 3    Shogunle
# 4      Bangui
# Name: name, dtype: str

# %%
df['rain']
# Out:
# 0                           NaN
# 1                           NaN
# 2    {'1h': 0.6900000000000001}
# 3                           NaN
# 4                           NaN
# Name: rain, dtype: object

# %%
df.loc[df['rain'].isnull()]
# Out:
#                               coord  \
# 0  {'lon': 36.6822, 'lat': -3.3869}
# 1   {'lon': 34.7519, 'lat': 0.2827}
# 3    {'lon': 3.3792, 'lat': 6.5244}
# 4   {'lon': 18.5628, 'lat': 4.3733}
#
#                                              weather      base  \
# 0  [{'id': 802, 'main': 'Clouds', 'description': ...  stations
# 1  [{'id': 804, 'main': 'Clouds', 'description': ...  stations
# 3  [{'id': 801, 'main': 'Clouds', 'description': ...  stations
# 4  [{'id': 804, 'main': 'Clouds', 'description': ...  stations
#
#                                                 main  visibility  \
# 0  {'temp': 291.12, 'feels_like': 290.77, 'temp_m...       10000
# 1  {'temp': 289.33, 'feels_like': 289.41, 'temp_m...       10000
# 3  {'temp': 297.56, 'feels_like': 298.35, 'temp_m...       10000
# 4  {'temp': 295.92, 'feels_like': 296.73, 'temp_m...       10000
#
#                                                 wind       clouds          dt  \
# ...

# %%
df.dropna(subset=['rain'])
# Out:
#                               coord  \
# 2  {'lon': 15.2663, 'lat': -4.4419}
#
#                                              weather      base  \
# 2  [{'id': 500, 'main': 'Rain', 'description': 'l...  stations
#
#                                                 main  visibility  \
# 2  {'temp': 301.61, 'feels_like': 302.46, 'temp_m...       10000
#
#                                      wind        clouds          dt  \
# 2  {'speed': 1.69, 'deg': 2, 'gust': 2.7}  {'all': 100}  1790198936
#
#                                                  sys  timezone       id  \
# 2  {'country': 'CD', 'sunrise': 1790138885, 'suns...      3600  2314302
#
#        name  cod                        rain
# 2  Kinshasa  200  {'1h': 0.6900000000000001}

# %%
df.isnull().sum()
# Out:
# coord         0
# weather       0
# base          0
# main          0
# visibility    0
# wind          0
# clouds        0
# dt            0
# sys           0
# timezone      0
# id            0
# name          0
# cod           0
# rain          4
# dtype: int64

# %%
df  = df.dropna(subset=['rain'])

# %%
df.isnull().sum()
# Out:
# coord         0
# weather       0
# base          0
# main          0
# visibility    0
# wind          0
# clouds        0
# dt            0
# sys           0
# timezone      0
# id            0
# name          0
# cod           0
# rain          0
# dtype: int64

# %%
df2 = pd.read_json('C:\\Users\\H\\Downloads\\data-engineering-75\\day05\\weather_data_5_cities.json')

# %%
df2.columns
# Out:
# Index(['coord', 'weather', 'base', 'main', 'visibility', 'wind', 'clouds',
#        'dt', 'sys', 'timezone', 'id', 'name', 'cod', 'rain'],
#       dtype='str')

# %%
df2.head(2)
# Out:
#                               coord  \
# 0  {'lon': 36.6822, 'lat': -3.3869}
# 1   {'lon': 34.7519, 'lat': 0.2827}
#
#                                              weather      base  \
# 0  [{'id': 802, 'main': 'Clouds', 'description': ...  stations
# 1  [{'id': 804, 'main': 'Clouds', 'description': ...  stations
#
#                                                 main  visibility  \
# 0  {'temp': 291.12, 'feels_like': 290.77, 'temp_m...       10000
# 1  {'temp': 289.33, 'feels_like': 289.41, 'temp_m...       10000
#
#                                                 wind       clouds          dt  \
# 0           {'speed': 2.4, 'deg': 139, 'gust': 3.21}  {'all': 27}  1790199067
# 1  {'speed': 1.4, 'deg': 45, 'gust': 1.4100000000...  {'all': 90}  1790199069
#
#                                                  sys  timezone      id  \
# 0  {'country': 'TZ', 'sunrise': 1790220119, 'suns...     10800  161325
# 1  {'country': 'KE', 'sunrise': 1790220589, 'suns...     10800  195272
#
# ...

# %%
df2['main'].iloc[0]
# Out:
# {'temp': 291.12,
#  'feels_like': 290.77,
#  'temp_min': 291.12,
#  'temp_max': 291.12,
#  'pressure': 1018,
#  'humidity': 69,
#  'sea_level': 1018,
#  'grnd_level': 870}

# %%
df2['main']
# Out:
# 0    {'temp': 291.12, 'feels_like': 290.77, 'temp_m...
# 1    {'temp': 289.33, 'feels_like': 289.41, 'temp_m...
# 2    {'temp': 301.61, 'feels_like': 302.46, 'temp_m...
# 3    {'temp': 297.56, 'feels_like': 298.35, 'temp_m...
# 4    {'temp': 295.92, 'feels_like': 296.73, 'temp_m...
# Name: main, dtype: object

# %%
df2['temperature'] = df2['main'].apply(lambda x: x['temp'])

# %%
df2.columns
# Out:
# Index(['coord', 'weather', 'base', 'main', 'visibility', 'wind', 'clouds',
#        'dt', 'sys', 'timezone', 'id', 'name', 'cod', 'rain', 'temperature'],
#       dtype='str')

# %%
df2.iloc[0]
# Out:
# coord                           {'lon': 36.6822, 'lat': -3.3869}
# weather        [{'id': 802, 'main': 'Clouds', 'description': ...
# base                                                    stations
# main           {'temp': 291.12, 'feels_like': 290.77, 'temp_m...
# visibility                                                 10000
# wind                    {'speed': 2.4, 'deg': 139, 'gust': 3.21}
# clouds                                               {'all': 27}
# dt                                                    1790199067
# sys            {'country': 'TZ', 'sunrise': 1790220119, 'suns...
# timezone                                                   10800
# id                                                        161325
# name                                                      Arusha
# cod                                                          200
# rain                                                         NaN
# ...

# %%
df2['temperature']
# Out:
# 0    291.12
# 1    289.33
# 2    301.61
# 3    297.56
# 4    295.92
# Name: temperature, dtype: float64

# %%
df3 = df2[df2['temperature'] > 295]

# %%
df3
# Out:
#                               coord  \
# 2  {'lon': 15.2663, 'lat': -4.4419}
# 3    {'lon': 3.3792, 'lat': 6.5244}
# 4   {'lon': 18.5628, 'lat': 4.3733}
#
#                                              weather      base  \
# 2  [{'id': 500, 'main': 'Rain', 'description': 'l...  stations
# 3  [{'id': 801, 'main': 'Clouds', 'description': ...  stations
# 4  [{'id': 804, 'main': 'Clouds', 'description': ...  stations
#
#                                                 main  visibility  \
# 2  {'temp': 301.61, 'feels_like': 302.46, 'temp_m...       10000
# 3  {'temp': 297.56, 'feels_like': 298.35, 'temp_m...       10000
# 4  {'temp': 295.92, 'feels_like': 296.73, 'temp_m...       10000
#
#                                        wind        clouds          dt  \
# 2    {'speed': 1.69, 'deg': 2, 'gust': 2.7}  {'all': 100}  1790198936
# 3  {'speed': 2.09, 'deg': 227, 'gust': 5.2}   {'all': 16}  1790198936
# 4  {'speed': 0.85, 'deg': 35, 'gust': 0.81}   {'all': 87}  1790199322
#
# ...
